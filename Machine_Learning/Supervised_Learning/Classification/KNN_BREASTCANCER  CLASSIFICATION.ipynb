# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

# %%
df =pd.read_csv("C:\\Users\\axay1\\Downloads\\BreastCancer.csv")
df
# Out:
#           Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  \
# 0    1000025             5          1           1              1
# 1    1002945             5          4           4              5
# 2    1015425             3          1           1              1
# 3    1016277             6          8           8              1
# 4    1017023             4          1           1              3
# ..       ...           ...        ...         ...            ...
# 694   776715             3          1           1              1
# 695   841769             2          1           1              1
# 696   888820             5         10          10              3
# 697   897471             4          8           6              4
# 698   897471             4          8           8              5
#
#      Epith.c.size  Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses  Class
# 0               2          1.0            3                1        1      0
# 1               7         10.0            3                2        1      0
# 2               2          2.0            3                1        1      0
# 3               3          4.0            3                7        1      0
# 4               2          1.0            3                1        1      0
# ..            ...          ...          ...              ...      ...    ...
# 694             3          2.0            1                1        1      0
# 695             2          1.0            1                1        1      0
# 696             7          3.0            8               10        2      1
# 697             3          4.0           10                6        1      1
# 698             4          5.0           10                4        1      1
#
# [699 rows x 11 columns]

# %%
df.head()
# Out:
#         Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  Epith.c.size  \
# 0  1000025             5          1           1              1             2
# 1  1002945             5          4           4              5             7
# 2  1015425             3          1           1              1             2
# 3  1016277             6          8           8              1             3
# 4  1017023             4          1           1              3             2
#
#    Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses  Class
# 0          1.0            3                1        1      0
# 1         10.0            3                2        1      0
# 2          2.0            3                1        1      0
# 3          4.0            3                7        1      0
# 4          1.0            3                1        1      0

# %%
df.tail()
# Out:
#          Id  Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  Epith.c.size  \
# 694  776715             3          1           1              1             3
# 695  841769             2          1           1              1             2
# 696  888820             5         10          10              3             7
# 697  897471             4          8           6              4             3
# 698  897471             4          8           8              5             4
#
#      Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses  Class
# 694          2.0            1                1        1      0
# 695          1.0            1                1        1      0
# 696          3.0            8               10        2      1
# 697          4.0           10                6        1      1
# 698          5.0           10                4        1      1

# %%
df.shape
# Out:
# (699, 11)

# %%
df.isnull().sum()
# Out:
# Id                  0
# Cl.thickness        0
# Cell.size           0
# Cell.shape          0
# Marg.adhesion       0
# Epith.c.size        0
# Bare.nuclei        16
# Bl.cromatin         0
# Normal.nucleoli     0
# Mitoses             0
# Class               0
# dtype: int64

# %%
df["Bare.nuclei"].fillna(df["Bare.nuclei"].median(), inplace= True)
df.isnull().sum()
# Out:
# Id                 0
# Cl.thickness       0
# Cell.size          0
# Cell.shape         0
# Marg.adhesion      0
# Epith.c.size       0
# Bare.nuclei        0
# Bl.cromatin        0
# Normal.nucleoli    0
# Mitoses            0
# Class              0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Id', 'Cl.thickness', 'Cell.size', 'Cell.shape', 'Marg.adhesion',
#        'Epith.c.size', 'Bare.nuclei', 'Bl.cromatin', 'Normal.nucleoli',
#        'Mitoses', 'Class'],
#       dtype='object')

# %%
corr = df.corr()

# %%
plt.figure(figsize=(10,8))
sns.heatmap(corr, 
            annot=True,      # values show karega
            cmap='coolwarm', # colors
            fmt='.2f')       # 2 decimal

plt.title('Correlation Heatmap')
plt.show()

# %%
corr_target = df.corr()[['Class']]

plt.figure(figsize=(4,8))
sns.heatmap(corr_target, annot=True, cmap='coolwarm')
plt.title('Feature vs Class Correlation')
plt.show()

# %%
x= df[['Cl.thickness', 'Cell.size', 'Cell.shape', 'Marg.adhesion',
       'Epith.c.size', 'Bare.nuclei', 'Bl.cromatin', 'Normal.nucleoli',
       'Mitoses']]
x
# Out:
#      Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  Epith.c.size  \
# 0               5          1           1              1             2
# 1               5          4           4              5             7
# 2               3          1           1              1             2
# 3               6          8           8              1             3
# 4               4          1           1              3             2
# ..            ...        ...         ...            ...           ...
# 694             3          1           1              1             3
# 695             2          1           1              1             2
# 696             5         10          10              3             7
# 697             4          8           6              4             3
# 698             4          8           8              5             4
#
#      Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses
# 0            1.0            3                1        1
# 1           10.0            3                2        1
# 2            2.0            3                1        1
# 3            4.0            3                7        1
# 4            1.0            3                1        1
# ..           ...          ...              ...      ...
# 694          2.0            1                1        1
# 695          1.0            1                1        1
# 696          3.0            8               10        2
# 697          4.0           10                6        1
# 698          5.0           10                4        1
#
# [699 rows x 9 columns]

# %%
y = df[['Class']]

y
# Out:
#      Class
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
# ..     ...
# 694      0
# 695      0
# 696      1
# 697      1
# 698      1
#
# [699 rows x 1 columns]

# %%
x_train, x_test, y_train, y_test = train_test_split(
    x, y, test_size=0.4, random_state=42
)
x_train
# Out:
#      Cl.thickness  Cell.size  Cell.shape  Marg.adhesion  Epith.c.size  \
# 278             1          1           1              1             2
# 116             8          3           3              1             2
# 228             1          1           1              1             1
# 697             4          8           6              4             3
# 319             4          4           4              4             6
# ..            ...        ...         ...            ...           ...
# 71              6         10           2              8            10
# 106            10         10          10              8             2
# 270             8          4           7              1             3
# 435            10          8          10              1             3
# 102             4          1           2              1             2
#
#      Bare.nuclei  Bl.cromatin  Normal.nucleoli  Mitoses
# 278          1.0            3                1        1
# 116          2.0            3                2        1
# 228          1.0            3                1        1
# 697          4.0           10                6        1
# 319          5.0            7                3        1
# ..           ...          ...              ...      ...
# 71           2.0            7                8       10
# 106         10.0            4                1        1
# 270         10.0            3                9        2
# 435         10.0            5                1        1
# 102          1.0            3                1        1
#
# [419 rows x 9 columns]

# %%
scaler= StandardScaler()
x_train = scaler.fit_transform(x_train)
x_test = scaler.fit_transform(x_train)

# %%
knn = KNeighborsClassifier()
knn.fit(x_train , y_train)
# Out:
# C:\Users\axay1\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\neighbors\_classification.py:243: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier()

# %%
pred = knn.predict(x_test)
print(accuracy_score(y_test, pred))
test_precision = precision_score(y_test, pred, average='weighted')
test_recall    = recall_score(y_test, pred, average='weighted')
test_f1        = f1_score(y_test, pred, average='weighted')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[69], line 2
#       1 pred = knn.predict(x_test)
# ----> 2 print(accuracy_score(y_test, pred))
#       3 test_precision = precision_score(y_test, pred, average='weighted')
#       4 test_recall    = recall_score(y_test, pred, average='weighted')
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
#     217     ):
# --> 218         return func(*args, **kwargs)
#     219 except InvalidParameterError as e:
#     220     # When the function is just a wrapper around an estimator, we allow
#     221     # the function to delegate validation to the estimator, but we replace
#     222     # the name of the estimator by the name of the function in the error
#     223     # message to avoid confusion.
#     224     msg = re.sub(
#     225         r"parameter of \w+ must be",
#     226         f"parameter of {func.__qualname__} must be",
#     227         str(e),
#     228     )
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_classification.py:411, in accuracy_score(y_true, y_pred, normalize, sample_weight)
#     409 # Compute accuracy for each possible representation
#     410 y_true, y_pred = attach_unique(y_true, y_pred)
# --> 411 y_type, y_true, y_pred, sample_weight = _check_targets(
#     412     y_true, y_pred, sample_weight
#     413 )
#     415 if y_type.startswith("multilabel"):
#     416     differing_labels = _count_nonzero(y_true - y_pred, xp=xp, device=device, axis=1)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\metrics\_classification.py:108, in _check_targets(y_true, y_pred, sample_weight)
#      77 """Check that y_true and y_pred belong to the same classification task.
#      78
#      79 This converts multiclass or binary types to a common shape, and raises a
#    (...)    105 sample_weight : array or None
#     106 """
#     107 xp, _ = get_namespace(y_true, y_pred, sample_weight)
# --> 108 check_consistent_length(y_true, y_pred, sample_weight)
#     109 type_true = type_of_target(y_true, input_name="y_true")
#     110 type_pred = type_of_target(y_pred, input_name="y_pred")
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\site-packages\sklearn\utils\validation.py:464, in check_consistent_length(*arrays)
#     462 lengths = [_num_samples(X) for X in arrays if X is not None]
#     463 if len(set(lengths)) > 1:
# --> 464     raise ValueError(
#     465         "Found input variables with inconsistent numbers of samples: %r"
#     466         % [int(l) for l in lengths]
#     467     )
#
# ValueError: Found input variables with inconsistent numbers of samples: [280, 419]

# %%
train_pred = knn.predict(x_train)
test_pred  = knn.predict(x_test)

from sklearn.metrics import accuracy_score

print("Train Accuracy:", accuracy_score(y_train, train_pred))
print("Test Accuracy:", accuracy_score(y_test, test_pred))
# Out:
# Train Accuracy: 0.9749552772808586
# Test Accuracy: 0.9857142857142858
